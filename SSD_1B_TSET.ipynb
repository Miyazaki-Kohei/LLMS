# %% [markdown]
# <a href="https://colab.research.google.com/github/Miyazaki-Kohei/LLMS/blob/main/SSD_1B_TSET.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/huggingface/diffusers
# !pip install transformers accelerate safetensors

from diffusers import StableDiffusionXLPipeline
import torch

# Initialize pipeline
pipe = StableDiffusionXLPipeline.from_pretrained("segmind/SSD-1B", torch_dtype=torch.float16, use_safetensors=True, variant="fp16")
pipe.to("cuda")

# Optional: if using torch < 2.0
# pipe.enable_xformers_memory_efficient_attention()

# Define prompts
prompt = "Sexy, attractive and beautiful woman." # Your prompt here
neg_prompt = "ugly, blurry, poor quality"  # Negative prompt here

# Generate and save 10 images
for i in range(10):
    image = pipe(prompt=prompt, negative_prompt=neg_prompt).images[0]
    image.save(f"image_{i}.png")
# Out:
# ...
#   Cloning https://github.com/huggingface/diffusers to /tmp/pip-req-build-rveal9l4
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/diffusers /tmp/pip-req-build-rveal9l4
#   Resolved https://github.com/huggingface/diffusers to commit 75ea54a1512ac443d517ab35cb9bf45f8d6f326e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 16.9 MB/s eta 0:00:00
# ...
#   Created wheel for diffusers: filename=diffusers-0.22.0.dev0-py3-none-any.whl size=1602970 sha256=ad46cf6833d59100031254eb018350145816d882686c609cea46da472bdf9924
#   Stored in directory: /tmp/pip-ephem-wheel-cache-p308a7n9/wheels/f7/7d/99/d361489e5762e3464b3811bc629e94cf5bf5ef44dd5c3c4d52
# Successfully built diffusers
# ...

# %%
# Define prompts
prompt = "Sexy, attractive and beautiful woman." # Your prompt here
neg_prompt = "ugly, blurry, poor quality"  # Negative prompt here

# Generate and save 10 images
for i in range(10):
    image = pipe(prompt=prompt, negative_prompt=neg_prompt).images[0]
    image.save(f"image_{i}.png")
# Out:
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]
